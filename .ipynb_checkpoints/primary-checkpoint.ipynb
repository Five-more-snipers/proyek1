# %%
# ===============================================================
# NOTEBOOK UTAMA UNTUK MENJALANKAN PIPELINE MODULAR
# ===============================================================

import warnings
warnings.filterwarnings('ignore')

import os
import tensorflow as tf
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext
from tfx.components import CsvExampleGen, StatisticsGen, SchemaGen, ExampleValidator, Transform, Tuner, Trainer, Evaluator, Pusher
from tfx.proto import trainer_pb2, pusher_pb2, example_gen_pb2
from tfx.dsl.components.common.resolver import Resolver
from tfx.dsl.input_resolution.strategies.latest_blessed_model_strategy import LatestBlessedModelStrategy
from tfx.types import Channel
from tfx.types.standard_artifacts import Model, ModelBlessing
import tensorflow_model_analysis as tfma
# Out:
# 2025-07-08 16:14:28.024143: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-08 16:14:28.151544: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-08 16:14:28.672213: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-08 16:14:28.672895: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-08 16:14:28.781043: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-08 16:14:29.003278: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-08 16:14:29.007268: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-08 16:14:44.596796: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import pandas as pd

# %%
PIPELINE_NAME = "raffihakim-pipeline"
SCHEMA_PIPELINE_NAME = "student-score-tfdv-schema"

PIPELINE_ROOT = os.path.join('pipelines', PIPELINE_NAME)
METADATA_PATH = os.path.join('metadata', PIPELINE_NAME, 'metadata.db')
SERVING_MODEL_DIR = os.path.join('serving_model', PIPELINE_NAME)
DATA_ROOT = 'data'

# %%
MODEL_NAME = "score-prediction-model"

# %%
serving_model_path = os.path.join(SERVING_MODEL_DIR, MODEL_NAME)

# %%
interactive_context = InteractiveContext(pipeline_root=PIPELINE_ROOT)
# Out:
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at pipelines/raffihakim-pipeline/metadata.sqlite.

# %%
origin = pd.read_csv("data/student_habits_performance.csv")
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %% [markdown]
# Data Ingestion (ExampleGen)

# %%
output = example_gen_pb2.Output(
    split_config = example_gen_pb2.SplitConfig(splits=[
        example_gen_pb2.SplitConfig.Split(name="train", hash_buckets=8),
        example_gen_pb2.SplitConfig.Split(name="eval", hash_buckets=2)
    ])
)

# %%
ingested_data = CsvExampleGen(input_base=DATA_ROOT, output_config=output)
interactive_context.run(ingested_data)
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 14
#     outputs:
#         examples: OutputChannel(artifact_type=Examples, producer_component_id=CsvExampleGen, output_key=examples, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))

# %% [markdown]
# Data Validation (StatisticGen)

# %%
stats = StatisticsGen(examples = ingested_data.outputs["examples"])
interactive_context.run(stats)
# Out:
# ExecutionResult(
#     component_id: StatisticsGen
#     execution_id: 15
#     outputs:
#         statistics: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=StatisticsGen, output_key=statistics, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))

# %%
interactive_context.show(stats.outputs['statistics'])
# Out:
# <b>Artifact at pipelines/raffihakim-pipeline/StatisticsGen/statistics/15</b><br/><br/>
# <style>html[theme=dark] iframe {background: white;}</style>
# <div><b>'train' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <div><b>'eval' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# SchemaGen

# %%
skema = SchemaGen(statistics=stats.outputs["statistics"])
interactive_context.run(skema)
# Out:
# ExecutionResult(
#     component_id: SchemaGen
#     execution_id: 16
#     outputs:
#         schema: OutputChannel(artifact_type=Schema, producer_component_id=SchemaGen, output_key=schema, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))

# %%
interactive_context.show(skema.outputs["schema"])
# Out:
# <b>Artifact at pipelines/raffihakim-pipeline/SchemaGen/schema/16</b><br/><br/>
#                                    Type  Presence Valency  \
# Feature name
# 'age'                               INT  required
# 'attendance_percentage'           FLOAT  required
# 'diet_quality'                   STRING  required
# 'exam_score'                      FLOAT  required
# 'exercise_frequency'                INT  required
# 'extracurricular_participation'  STRING  required
# 'gender'                         STRING  required
# 'internet_quality'               STRING  required
# 'mental_health_rating'              INT  required
# 'netflix_hours'                   FLOAT  required
# 'parental_education_level'       STRING  required
# 'part_time_job'                  STRING  required
# 'sleep_hours'                     FLOAT  required
# 'social_media_hours'              FLOAT  required
# 'student_id'                      BYTES  required
# 'study_hours_per_day'             FLOAT  required
#
#                                                           Domain
# Feature name
# 'age'                                                          -
# 'attendance_percentage'                                        -
# 'diet_quality'                                    'diet_quality'
# 'exam_score'                                                   -
# 'exercise_frequency'                                           -
# 'extracurricular_participation'  'extracurricular_participation'
# 'gender'                                                'gender'
# 'internet_quality'                            'internet_quality'
# 'mental_health_rating'                                         -
# 'netflix_hours'                                                -
# 'parental_education_level'            'parental_education_level'
# 'part_time_job'                                  'part_time_job'
# 'sleep_hours'                                                  -
# 'social_media_hours'                                           -
# 'student_id'                                                   -
# 'study_hours_per_day'                                          -
#                                                                       Values
# Domain
# 'diet_quality'                                        'Fair', 'Good', 'Poor'
# 'extracurricular_participation'                                  'No', 'Yes'
# 'gender'                                           'Female', 'Male', 'Other'
# 'internet_quality'                                 'Average', 'Good', 'Poor'
# 'parental_education_level'       'Bachelor', 'High School', 'Master', 'None'
# 'part_time_job'                                                  'No', 'Yes'

# %% [markdown]
# ExampleValidator

# %%
validing = ExampleValidator(
    statistics=stats.outputs["statistics"],
    schema=skema.outputs["schema"]
)
interactive_context.run(validing)
# Out:
# ExecutionResult(
#     component_id: ExampleValidator
#     execution_id: 17
#     outputs:
#         anomalies: OutputChannel(artifact_type=ExampleAnomalies, producer_component_id=ExampleValidator, output_key=anomalies, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))

# %%
interactive_context.show(validing.outputs["anomalies"])
# Out:
# <b>Artifact at pipelines/raffihakim-pipeline/ExampleValidator/anomalies/17</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>
# <div><b>'eval' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>

# %% [markdown]
# Data Preprocessing (Transform)

# %%
TRANSFORM_MODULE_FILE = "student_transform.py"
transform = Transform(
    examples=ingested_data.outputs["examples"],
    schema=skema.outputs['schema'],
    module_file=os.path.abspath(TRANSFORM_MODULE_FILE)
)
interactive_context.run(transform)
# Out:
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying student_trainer.py -> build/lib
# copying student_transform.py -> build/lib
# copying student_tuner.py -> build/lib
# installing to /tmp/tmpkhixztv5
# running install
# running install_lib
# /mnt/d/proyek1/mlops/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# copying build/lib/student_transform.py -> /tmp/tmpkhixztv5
# copying build/lib/student_trainer.py -> /tmp/tmpkhixztv5
# copying build/lib/student_tuner.py -> /tmp/tmpkhixztv5
# running install_egg_info
# running egg_info
# creating tfx_user_code_Transform.egg-info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmpkhixztv5/tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.egg-info
# running install_scripts
# creating /tmp/tmpkhixztv5/tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/WHEEL
# creating '/tmp/tmp39j9m5tu/tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4-py3-none-any.whl' and adding '/tmp/tmpkhixztv5' to it
# adding 'student_trainer.py'
# adding 'student_transform.py'
# adding 'student_tuner.py'
# adding 'tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/RECORD'
# removing /tmp/tmpkhixztv5
# Processing ./pipelines/raffihakim-pipeline/_wheels/tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4
# Processing ./pipelines/raffihakim-pipeline/_wheels/tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4
# Processing ./pipelines/raffihakim-pipeline/_wheels/tfx_user_code_Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4
# 2025-07-08 16:17:15.076905: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-08 16:17:15.078696: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# INFO:tensorflow:Assets written to: pipelines/raffihakim-pipeline/Transform/transform_graph/18/.temp_path/tftransform_tmp/c631065ac8b148ecba19ab8ddc4d3aa5/assets
# INFO:tensorflow:Assets written to: pipelines/raffihakim-pipeline/Transform/transform_graph/18/.temp_path/tftransform_tmp/c631065ac8b148ecba19ab8ddc4d3aa5/assets
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# ExecutionResult(
#     component_id: Transform
#     execution_id: 18
#     outputs:
#         transform_graph: OutputChannel(artifact_type=TransformGraph, producer_component_id=Transform, output_key=transform_graph, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         transformed_examples: OutputChannel(artifact_type=Examples, producer_component_id=Transform, output_key=transformed_examples, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         updated_analyzer_cache: OutputChannel(artifact_type=TransformCache, producer_component_id=Transform, output_key=updated_analyzer_cache, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         pre_transform_schema: OutputChannel(artifact_type=Schema, producer_component_id=Transform, output_key=pre_transform_schema, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         pre_transform_stats: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=Transform, output_key=pre_transform_stats, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         post_transform_schema: OutputChannel(artifact_type=Schema, producer_component_id=Transform, output_key=post_transform_schema, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         post_transform_stats: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=Transform, output_key=post_transform_stats, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         post_transform_anomalies: OutputChannel(artifact_type=ExampleAnomalies, producer_component_id=Transform, output_key=post_transform_anomalies, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))

# %% [markdown]
# Model Development (Tuner)

# %%
TUNER_MODULE_FILE = "student_tuner.py"
tuner = Tuner(
    module_file=os.path.abspath(TUNER_MODULE_FILE),
    examples=transform.outputs['transformed_examples'],
    transform_graph=transform.outputs['transform_graph'],
    schema=skema.outputs['schema'],
    train_args=trainer_pb2.TrainArgs(num_steps=500),
    eval_args=trainer_pb2.EvalArgs(num_steps=100)
)
interactive_context.run(tuner)
# Out:
# Trial 10 Complete [00h 00m 39s]
# val_root_mean_squared_error: 4.704137802124023
#
# Best val_root_mean_squared_error So Far: 4.645150184631348
# Total elapsed time: 00h 05m 48s
# Results summary
# Results in pipelines/raffihakim-pipeline/.temp/19/student_performance_tuning
# Showing 10 best trials
# Objective(name="val_root_mean_squared_error", direction="min")
#
# Trial 01 summary
# Hyperparameters:
# num_layers: 2
# units_0: 96
# dropout: 0.5
# learning_rate: 0.001
# units_1: 224
# Score: 4.645150184631348
#
# Trial 02 summary
# Hyperparameters:
# num_layers: 1
# units_0: 128
# dropout: 0.2
# learning_rate: 0.001
# units_1: 128
# Score: 4.6631951332092285
#
# Trial 05 summary
# Hyperparameters:
# num_layers: 2
# units_0: 192
# dropout: 0.30000000000000004
# learning_rate: 0.01
# units_1: 256
# units_2: 192
# Score: 4.672269821166992
#
# Trial 07 summary
# Hyperparameters:
# num_layers: 2
# units_0: 128
# dropout: 0.2
# learning_rate: 0.001
# units_1: 256
# units_2: 32
# Score: 4.691691875457764
#
# Trial 09 summary
# Hyperparameters:
# num_layers: 3
# units_0: 256
# dropout: 0.2
# learning_rate: 0.01
# units_1: 128
# units_2: 192
# Score: 4.704137802124023
#
# Trial 08 summary
# Hyperparameters:
# num_layers: 2
# units_0: 256
# dropout: 0.5
# learning_rate: 0.0001
# units_1: 224
# units_2: 160
# Score: 4.7256927490234375
#
# Trial 00 summary
# Hyperparameters:
# num_layers: 2
# units_0: 256
# dropout: 0.30000000000000004
# learning_rate: 0.001
# units_1: 32
# Score: 4.785691738128662
#
# Trial 03 summary
# Hyperparameters:
# num_layers: 2
# units_0: 192
# dropout: 0.4
# learning_rate: 0.0001
# units_1: 64
# Score: 5.224221706390381
#
# Trial 04 summary
# Hyperparameters:
# num_layers: 3
# units_0: 128
# dropout: 0.2
# learning_rate: 0.0001
# units_1: 32
# units_2: 32
# Score: 5.399965286254883
#
# Trial 06 summary
# Hyperparameters:
# num_layers: 1
# units_0: 32
# dropout: 0.4
# learning_rate: 0.01
# units_1: 128
# units_2: 64
# Score: 5.8899030685424805
# ExecutionResult(
#     component_id: Tuner
#     execution_id: 19
#     outputs:
#         best_hyperparameters: OutputChannel(artifact_type=HyperParameters, producer_component_id=Tuner, output_key=best_hyperparameters, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         tuner_results: OutputChannel(artifact_type=TunerResults, producer_component_id=Tuner, output_key=tuner_results, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))

# %% [markdown]
# Trainer

# %%
TRAINER_MODULE_FILE = "student_trainer.py"
trainer = Trainer(
    module_file=os.path.abspath(TRAINER_MODULE_FILE),
    examples=transform.outputs['transformed_examples'],
    transform_graph=transform.outputs['transform_graph'],
    schema=skema.outputs['schema'],
    hyperparameters=tuner.outputs['best_hyperparameters'],
    train_args=trainer_pb2.TrainArgs(num_steps=500),
    eval_args=trainer_pb2.EvalArgs(num_steps=100),
)
interactive_context.run(trainer)
# Out:
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying student_trainer.py -> build/lib
# copying student_transform.py -> build/lib
# copying student_tuner.py -> build/lib
# installing to /tmp/tmpfhe_94mm
# running install
# running install_lib
# copying build/lib/student_transform.py -> /tmp/tmpfhe_94mm
# copying build/lib/student_trainer.py -> /tmp/tmpfhe_94mm
# copying build/lib/student_tuner.py -> /tmp/tmpfhe_94mm
# running install_egg_info
# /mnt/d/proyek1/mlops/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmpfhe_94mm/tfx_user_code_Trainer-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.egg-info
# running install_scripts
# creating /tmp/tmpfhe_94mm/tfx_user_code_Trainer-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/WHEEL
# creating '/tmp/tmp7okku9d5/tfx_user_code_Trainer-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4-py3-none-any.whl' and adding '/tmp/tmpfhe_94mm' to it
# adding 'student_trainer.py'
# adding 'student_transform.py'
# adding 'student_tuner.py'
# adding 'tfx_user_code_Trainer-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4.dist-info/RECORD'
# removing /tmp/tmpfhe_94mm
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# Processing ./pipelines/raffihakim-pipeline/_wheels/tfx_user_code_Trainer-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4-py3-none-any.whl
# Installing collected packages: tfx-user-code-Trainer
# Successfully installed tfx-user-code-Trainer-0.0+8f107ff5f9d4e7be01e3c4fe22a91a5e2c0304b9cf3ca7e1363329c1a03b93a4
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  age_xf (InputLayer)         [(None, 1)]                  0         []
#
#  study_hours_per_day_xf (In  [(None, 1)]                  0         []
#  putLayer)
#
#  social_media_hours_xf (Inp  [(None, 1)]                  0         []
#  utLayer)
#
#  netflix_hours_xf (InputLay  [(None, 1)]                  0         []
#  er)
#
#  attendance_percentage_xf (  [(None, 1)]                  0         []
#  InputLayer)
#
#  sleep_hours_xf (InputLayer  [(None, 1)]                  0         []
#  )
#
#  mental_health_rating_xf (I  [(None, 1)]                  0         []
#  nputLayer)
#
#  exercise_frequency_xf (Inp  [(None, 1)]                  0         []
#  utLayer)
#
#  concatenate_1 (Concatenate  (None, 8)                    0         ['age_xf[0][0]',
#  )                                                                   'study_hours_per_day_xf[0][0]
#                                                                     ',
#                                                                      'social_media_hours_xf[0][0]'
#                                                                     , 'netflix_hours_xf[0][0]',
#                                                                      'attendance_percentage_xf[0][
#                                                                     0]',
#                                                                      'sleep_hours_xf[0][0]',
#                                                                      'mental_health_rating_xf[0][0
#                                                                     ]',
#                                                                      'exercise_frequency_xf[0][0]'
#                                                                     ]
#
#  dense_4 (Dense)             (None, 128)                  1152      ['concatenate_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 64)                   8256      ['dropout_1[0][0]']
#
#  dense_6 (Dense)             (None, 1)                    65        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 9473 (37.00 KB)
# Trainable params: 9473 (37.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/15
# 500/500 [==============================] - 2s 3ms/step - loss: 282.2718 - root_mean_squared_error: 16.8009 - val_loss: 46.3622 - val_root_mean_squared_error: 6.8090
# Epoch 2/15
# 500/500 [==============================] - 1s 3ms/step - loss: 81.3334 - root_mean_squared_error: 9.0185 - val_loss: 37.7994 - val_root_mean_squared_error: 6.1481
# Epoch 3/15
# 500/500 [==============================] - 1s 3ms/step - loss: 70.3885 - root_mean_squared_error: 8.3898 - val_loss: 80.5718 - val_root_mean_squared_error: 8.9762
# Epoch 4/15
# 500/500 [==============================] - 1s 3ms/step - loss: 63.6725 - root_mean_squared_error: 7.9795 - val_loss: 109.1225 - val_root_mean_squared_error: 10.4462
# Epoch 5/15
# 500/500 [==============================] - 1s 2ms/step - loss: 59.2368 - root_mean_squared_error: 7.6965 - val_loss: 150.5831 - val_root_mean_squared_error: 12.2712
# Epoch 6/15
# 500/500 [==============================] - 1s 2ms/step - loss: 55.8455 - root_mean_squared_error: 7.4730 - val_loss: 183.7906 - val_root_mean_squared_error: 13.5569
# Epoch 7/15
# 500/500 [==============================] - 1s 2ms/step - loss: 51.4760 - root_mean_squared_error: 7.1747 - val_loss: 242.8722 - val_root_mean_squared_error: 15.5844
# Epoch 8/15
# 500/500 [==============================] - 1s 2ms/step - loss: 46.8007 - root_mean_squared_error: 6.8411 - val_loss: 217.0782 - val_root_mean_squared_error: 14.7336
# Epoch 9/15
# 500/500 [==============================] - 1s 2ms/step - loss: 43.5190 - root_mean_squared_error: 6.5969 - val_loss: 225.8617 - val_root_mean_squared_error: 15.0287
# Epoch 10/15
# 500/500 [==============================] - 0s 367us/step - loss: 41.9518 - root_mean_squared_error: 6.4770 - val_loss: 275.8687 - val_root_mean_squared_error: 16.6093
# Epoch 11/15
# 500/500 [==============================] - 1s 3ms/step - loss: 40.2336 - root_mean_squared_error: 6.3430 - val_loss: 247.9535 - val_root_mean_squared_error: 15.7465
# Epoch 12/15
# 500/500 [==============================] - 1s 2ms/step - loss: 39.1864 - root_mean_squared_error: 6.2599 - val_loss: 303.6838 - val_root_mean_squared_error: 17.4265
# Epoch 13/15
# 500/500 [==============================] - 1s 2ms/step - loss: 38.5013 - root_mean_squared_error: 6.2049 - val_loss: 298.6892 - val_root_mean_squared_error: 17.2826
# Epoch 14/15
# 500/500 [==============================] - 1s 2ms/step - loss: 37.1117 - root_mean_squared_error: 6.0919 - val_loss: 344.2386 - val_root_mean_squared_error: 18.5537
# Epoch 15/15
# 500/500 [==============================] - 1s 2ms/step - loss: 36.4275 - root_mean_squared_error: 6.0355 - val_loss: 324.1387 - val_root_mean_squared_error: 18.0039
# INFO:tensorflow:Assets written to: pipelines/raffihakim-pipeline/Trainer/model/20/Format-Serving/assets
# INFO:tensorflow:Assets written to: pipelines/raffihakim-pipeline/Trainer/model/20/Format-Serving/assets
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 20
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=Trainer, output_key=model, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         model_run: OutputChannel(artifact_type=ModelRun, producer_component_id=Trainer, output_key=model_run, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))

# %% [markdown]
# Resolver

# %%
model_resolver = Resolver(
    strategy_class=LatestBlessedModelStrategy,
    model=Channel(type=Model),
    model_blessing=Channel(type=ModelBlessing)
).with_id('Latest_blessed_model_resolver')
interactive_context.run(model_resolver)
# Out:
# ExecutionResult(
#     component_id: Latest_blessed_model_resolver
#     execution_id: 21
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=Latest_blessed_model_resolver, output_key=model, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         model_blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=Latest_blessed_model_resolver, output_key=model_blessing, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))

# %% [markdown]
# Evaluator

# %%
# BUAT EVAL_CONFIG SEDERHANA UNTUK DIAGNOSIS
simple_eval_config = tfma.EvalConfig(
    model_specs=[
        tfma.ModelSpec(label_key='exam_score_xf') # Hanya satu model, tanpa nama
    ],
    slicing_specs=[
        tfma.SlicingSpec()
    ],
    metrics_specs=[
        tfma.MetricsSpec(
            metrics=[
                tfma.MetricConfig(class_name='ExampleCount'),
                tfma.MetricConfig(class_name='MeanSquaredError'),
                tfma.MetricConfig(class_name='RootMeanSquaredError')
            ]
        )
    ]
)

# %%
# JALANKAN ULANG EVALUATOR TANPA BASELINE
evaluator_simple = Evaluator(
    examples=transform.outputs['transformed_examples'],
    model=trainer.outputs['model'],
    # baseline_model=model_resolver.outputs['model'], # <-- HAPUS ATAU BERI KOMENTAR BARIS INI
    eval_config=simple_eval_config # Gunakan config sederhana yang baru
)

interactive_context.run(evaluator_simple)
# Out:
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# ExecutionResult(
#     component_id: Evaluator
#     execution_id: 24
#     outputs:
#         evaluation: OutputChannel(artifact_type=ModelEvaluation, producer_component_id=Evaluator, output_key=evaluation, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False)
#         blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=Evaluator, output_key=blessing, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))

# %% [markdown]
# TFMA Visualization

# %%
hasil_evaluasi_uri = evaluator.outputs['evaluation'].get()[0].uri
hasil_tfma = tfma.load_eval_result(hasil_evaluasi_uri)

tfma.view.render_slicing_metrics(hasil_tfma)
# Out:
# SlicingMetricsViewer(config={'weightedExamplesColumn': 'example_count'}, data=[{'slice': 'Overall', 'metrics':…

# %%
# Komponen Pusher sekarang menjadi lebih bersih dan menggunakan
# variabel `serving_model_path` yang sudah kita definisikan.

pusher = Pusher(
    model=trainer.outputs['model'],
    model_blessing=evaluator.outputs['blessing'],
    push_destination=pusher_pb2.PushDestination(
        filesystem=pusher_pb2.PushDestination.Filesystem(
            base_directory=serving_model_path  # <-- Menggunakan variabel
        )
    ))

# Jalankan komponen (tidak ada perubahan di sini)
interactive_context.run(pusher)
# Out:
# ExecutionResult(
#     component_id: Pusher
#     execution_id: 25
#     outputs:
#         pushed_model: OutputChannel(artifact_type=PushedModel, producer_component_id=Pusher, output_key=pushed_model, additional_properties={}, additional_custom_properties={}, _input_trigger=None, _is_async=False))
